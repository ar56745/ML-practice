# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('heart_2020_cleaned.csv')
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
na_values = df.isna().sum()
print(na_values)
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()
df['GenHealth'] = ordinal_encoder.fit_transform(df[['GenHealth']])
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df['Smoking'] = ordinal_encoder.fit_transform(df[['Smoking']])
df['AlcoholDrinking'] = ordinal_encoder.fit_transform(df[['AlcoholDrinking']])
df['Stroke'] = ordinal_encoder.fit_transform(df[['Stroke']])
df['DiffWalking'] = ordinal_encoder.fit_transform(df[['DiffWalking']])
df['Sex'] = ordinal_encoder.fit_transform(df[['Sex']])
df['Race'] = ordinal_encoder.fit_transform(df[['Race']])
df['Diabetic'] = ordinal_encoder.fit_transform(df[['Diabetic']])
df['PhysicalActivity'] = ordinal_encoder.fit_transform(df[['PhysicalActivity']])
df['Asthma'] = ordinal_encoder.fit_transform(df[['Asthma']])
df['KidneyDisease'] = ordinal_encoder.fit_transform(df[['KidneyDisease']])
df['SkinCancer'] = ordinal_encoder.fit_transform(df[['SkinCancer']])

df['HeartDisease'] = ordinal_encoder.fit_transform(df[['HeartDisease']])
df
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                0.0  16.60      1.0              0.0     0.0             3.0
# 1                0.0  20.34      0.0              0.0     1.0             0.0
# 2                0.0  26.58      1.0              0.0     0.0            20.0
# 3                0.0  24.21      0.0              0.0     0.0             0.0
# 4                0.0  23.71      0.0              0.0     0.0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790           1.0  27.41      1.0              0.0     0.0             7.0
# 319791           0.0  29.84      1.0              0.0     0.0             0.0
# 319792           0.0  24.24      0.0              0.0     0.0             0.0
# 319793           0.0  32.81      0.0              0.0     0.0             0.0
# 319794           0.0  46.56      0.0              0.0     0.0             0.0
#
# ...

# %%
df['AgeCategory'] = df['AgeCategory'].str.replace('80 or older', '80-100')
df['AgeCategory'] = df['AgeCategory'].apply(lambda x: (int(x.split('-')[0]) + int(x.split('-')[1])) / 2)
df
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                0.0  16.60      1.0              0.0     0.0             3.0
# 1                0.0  20.34      0.0              0.0     1.0             0.0
# 2                0.0  26.58      1.0              0.0     0.0            20.0
# 3                0.0  24.21      0.0              0.0     0.0             0.0
# 4                0.0  23.71      0.0              0.0     0.0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790           1.0  27.41      1.0              0.0     0.0             7.0
# 319791           0.0  29.84      1.0              0.0     0.0             0.0
# 319792           0.0  24.24      0.0              0.0     0.0             0.0
# 319793           0.0  32.81      0.0              0.0     0.0             0.0
# 319794           0.0  46.56      0.0              0.0     0.0             0.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

X = df.iloc[:, 1:]
y = df.iloc[:, 0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8433626436853494

# %%
new_prediction1 = model.predict([[0,16.60,1,0,0,3,30,0,0,57,5,2,1,4,5,1,0,1]])
new_prediction2 = model.predict([[1,20,1,1,1,2,25,1,1,80,4,2,1,2,5,1,1,1]])
print(new_prediction1[0])
print(new_prediction2[0])
# Out:
# 1.0
# 1.0
